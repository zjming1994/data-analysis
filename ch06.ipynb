# %% [markdown]
# # Data Loading, Storage,

# %%
import numpy as np
import pandas as pd
np.random.seed(12345)
import matplotlib.pyplot as plt
plt.rc('figure', figsize=(10, 6))
np.set_printoptions(precision=4, suppress=True)

# %% [markdown]
# ## Reading and Writing Data in Text Format

# %% [markdown]
# ####  !cat ch06/ex1.csv 是linux的查看csv文件的命令。但windows下要用 !type examples\ex1.csv

# %%
# !type examples\ex1.csv
# Out:
# a,b,c,d,message
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %% [markdown]
# #### 读csv文件的两种方法
# #### 1. pd.read_csv， 默认参数直接读入第一行为列名，行序号是0 1 2 3 4
# #### 2. pd.read_table，需要加参数 sep=','

# %%
df = pd.read_csv('examples/ex1.csv')
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_table('examples/ex1.csv', sep=',')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !type examples\ex2.csv
# Out:
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo

# %% [markdown]
# #### pd.read_csv 中，可以指定参数，要不要列名
# #### header=None 不用列名
# #### names=列表 指定列名

# %%
pd.read_csv('examples/ex2.csv', header=None)
pd.read_csv('examples/ex2.csv', names=['a', 'b', 'c', 'd', 'message'])
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# #### index_col 指定哪一列作为索引（主键 唯一标识）
# #### index_col为列表时 可以作为层次索引

# %%
names = ['a', 'b', 'c', 'd', 'message']
pd.read_csv('examples/ex2.csv', names=names, index_col='message')
# Out:
#          a   b   c   d
# message
# hello    1   2   3   4
# world    5   6   7   8
# foo      9  10  11  12

# %%
# !type examples\csv_mindex.csv
parsed = pd.read_csv('examples/csv_mindex.csv',
                     index_col=['key1', 'key2'])
parsed
# Out:
# key1,key2,value1,value2
# one,a,1,2
# one,b,3,4
# one,c,5,6
# one,d,7,8
# two,a,9,10
# two,b,11,12
# two,c,13,14
# two,d,15,16
#            value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %% [markdown]
# #### list(open(path))是一种逐行读取txt文件并把每一行作为list的一个元素的操作

# %%
list(open('examples/ex3.txt'))
# Out:
# ['            A         B         C\n',
#  'aaa -0.264438 -1.026059 -0.619500\n',
#  'bbb  0.927272  0.302904 -0.032399\n',
#  'ccc -0.264273 -0.386314 -0.217601\n',
#  'ddd -0.871858 -0.348382  1.100491\n']

# %% [markdown]
# ####  sep='\s+'，可以读取\n每行结尾的txt文件

# %%
result = pd.read_table('examples/ex3.txt', sep='\s+')
result
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %% [markdown]
# #### pd.read_csv 中加入参数 skiprows=列表 去除一些指定的行

# %%
# !type examples\ex4.csv
pd.read_csv('examples/ex4.csv', skiprows=[0, 2, 3])
# Out:
# # hey!
# a,b,c,d,message
# # just wanted to make things more difficult for you
# # who reads CSV files with computers, anyway?
# 1,2,3,4,hello
# 5,6,7,8,world
# 9,10,11,12,foo
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %% [markdown]
# #### 读取的csv中包含NA时，这个位置是NaN
# #### pd.isnull(df) 为包含True和False的表格，判断每一个位置是不是NaN

# %%
# !type examples\ex5.csv
result = pd.read_csv('examples/ex5.csv')
result
pd.isnull(result)
# Out:
# something,a,b,c,d,message
# one,1,2,3,4,NA
# two,5,6,,8,world
# three,9,10,11,12,foo
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
result = pd.read_csv('examples/ex5.csv', na_values=['NULL'])
result
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# #### 指定某些位置为NaN

# %%
sentinels = {'message': ['foo', 'NA'], 'something': ['two']}
pd.read_csv('examples/ex5.csv', na_values=sentinels)
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       NaN  5   6   NaN   8   world
# 2     three  9  10  11.0  12     NaN

# %% [markdown]
# ### Reading Text Files in Pieces

# %% [markdown]
# #### 截断展示一个大表格：
# #### 1. pd.options.display.max_rows= 全局设定需要展示的行数
# #### 2. pd.read_csv 中，nrows= 为读取前几行

# %%
pd.options.display.max_rows = 10

# %%
result = pd.read_csv('examples/ex6.csv')
result
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]

# %%
pd.read_csv('examples/ex6.csv', nrows=5)
# Out:
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q

# %% [markdown]
# #### 有时，处于节约内存的考虑，加入chunksize= 迭代读取，read_csv所返回的这个TextParser对象使你可以根据chunksize对文件进行逐块迭代。
# #### 比如说，我们可以迭代处理ex6.csv，将值计数聚合到"key"列中。

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)
chunker

# %%
chunker = pd.read_csv('examples/ex6.csv', chunksize=1000)

tot = pd.Series([])
for piece in chunker:
    tot = tot.add(piece['key'].value_counts(), fill_value=0)

tot = tot.sort_values(ascending=False)
# Out:
# <ipython-input-34-cbca59bbb936>:3: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   tot = pd.Series([])

# %%
tot[:10]
# Out:
# E    368.0
# X    364.0
# L    346.0
# O    343.0
# Q    340.0
# M    338.0
# J    337.0
# F    335.0
# K    334.0
# H    330.0
# dtype: float64

# %% [markdown]
# ### Writing Data to Text Format

# %%
data = pd.read_csv('examples/ex5.csv')
data
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %% [markdown]
# ####  data.to_csv 用于写文件，默认的写法，NaN是不写入的。

# %%
data.to_csv('examples/out.csv')
# !type examples\out.csv
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,
# 1,two,5,6,,8,world
# 2,three,9,10,11.0,12,foo

# %% [markdown]
# #### import sys 搭配 data.to_csv 中的 sys.stdout 使用，可以在输出界面展示结果，并且可以指定分隔符。（相当于把csv文件打印出来了）

# %%
import sys
data.to_csv(sys.stdout, sep='|')
# Out:
# |something|a|b|c|d|message
# 0|one|1|2|3.0|4|
# 1|two|5|6||8|world
# 2|three|9|10|11.0|12|foo

# %% [markdown]
# #### 默认NaN不写，但也可以使用 na_rep 指定关键字

# %%
data.to_csv(sys.stdout, na_rep='NULL')
# Out:
# ,something,a,b,c,d,message
# 0,one,1,2,3.0,4,NULL
# 1,two,5,6,NULL,8,world
# 2,three,9,10,11.0,12,foo

# %% [markdown]
# #### 可以用 index=False, header=False 避免写入行名和列名。
# #### 也可以指定columns，选择写入的列。

# %%
data.to_csv(sys.stdout, index=False, header=False)
# Out:
# one,1,2,3.0,4,
# two,5,6,,8,world
# three,9,10,11.0,12,foo

# %%
data.to_csv(sys.stdout, index=False, columns=['a', 'b', 'c'])
# Out:
# a,b,c
# 1,2,3.0
# 5,6,
# 9,10,11.0

# %% [markdown]
# #### pd.date_range 可以生成时间序列的 时间戳 （后面章节可以用）
# #### pd.Series 生成 一个序列（不是df）

# %%
dates = pd.date_range('1/1/2000', periods=7)
ts = pd.Series(np.arange(7), index=dates)
ts.to_csv('examples/tseries.csv')
# !type examples\tseries.csv
# Out:
# ,0
# 2000-01-01,0
# 2000-01-02,1
# 2000-01-03,2
# 2000-01-04,3
# 2000-01-05,4
# 2000-01-06,5
# 2000-01-07,6

# %% [markdown]
# ### Working with Delimited Formats

# %% [markdown]
# ### 太复杂了，我可以用正则

# %%
# !type examples\ex7.csv
# Out:
# "a","b","c"
# "1","2","3"
# "1","2","3"

# %%
import csv
f = open('examples/ex7.csv')

reader = csv.reader(f)

# %%
for line in reader:
    print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['1', '2', '3']

# %%
with open('examples/ex7.csv') as f:
    lines = list(csv.reader(f))

# %%
header, values = lines[0], lines[1:]

# %%
data_dict = {h: v for h, v in zip(header, zip(*values))}
data_dict
# Out:
# {'a': ('1', '1'), 'b': ('2', '2'), 'c': ('3', '3')}

# %%
class my_dialect(csv.Dialect):
    lineterminator = '\n'
    delimiter = ';'
    quotechar = '"'
    quoting = csv.QUOTE_MINIMAL

# %%
reader = csv.reader(f, dialect=my_dialect)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-52ac1fdbe3c8> in <module>
# ----> 1 reader = csv.reader(f, dialect=my_dialect)
#
# ValueError: I/O operation on closed file.

# %%
reader = csv.reader(f, delimiter='|')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-cb03ed6e28ac> in <module>
# ----> 1 reader = csv.reader(f, delimiter='|')
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# with open('mydata.csv', 'w') as f:
#     writer = csv.writer(f, dialect=my_dialect)
#     writer.writerow(('one', 'two', 'three'))
#     writer.writerow(('1', '2', '3'))
#     writer.writerow(('4', '5', '6'))
#     writer.writerow(('7', '8', '9'))

# %% [markdown]
# ### JSON Data

# %% [markdown]
# #### json格式可以是很长的字符串
# #### import json 和 json.loads 用于读出json格式的文件
# #### 信息是由字典形式记录的，可以把字典读进去

# %%
obj = """
{"name": "Wes",
 "places_lived": ["United States", "Spain", "Germany"],
 "pet": null,
 "siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
              {"name": "Katie", "age": 38,
               "pets": ["Sixes", "Stache", "Cisco"]}]
}
"""

# %%
import json
result = json.loads(obj)
result
# Out:
# {'name': 'Wes',
#  'places_lived': ['United States', 'Spain', 'Germany'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 30, 'pets': ['Zeus', 'Zuko']},
#   {'name': 'Katie', 'age': 38, 'pets': ['Sixes', 'Stache', 'Cisco']}]}

# %%
asjson = json.dumps(result)

# %%
siblings = pd.DataFrame(result['siblings'], columns=['name', 'age'])
siblings
# Out:
#     name  age
# 0  Scott   30
# 1  Katie   38

# %% [markdown]
# #### 将数据从pandas输出到JSON，使用to_json

# %%
# !type examples\example.json
# Out:
# [{"a": 1, "b": 2, "c": 3},
#  {"a": 4, "b": 5, "c": 6},
#  {"a": 7, "b": 8, "c": 9}]

# %%
data = pd.read_json('examples/example.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
print(data.to_json())
# Out:
# {"a":{"0":1,"1":4,"2":7},"b":{"0":2,"1":5,"2":8},"c":{"0":3,"1":6,"2":9}}

# %%
print(data.to_json(orient='records'))
# Out:
# [{"a":1,"b":2,"c":3},{"a":4,"b":5,"c":6},{"a":7,"b":8,"c":9}]

# %% [markdown]
# ### XML and HTML: Web Scraping

# %% [markdown]
# conda install lxml
# pip install beautifulsoup4 html5lib

# %% [markdown]
# #### pd.read_html 读取html文件
# #### 形如September 23, 2016 的数据可以用 .dt.year.value_counts() 类似命令处理
# ### Python有许多可以读写常见的HTML和XML格式数据的库，包括lxml、Beautiful Soup和html5lib。lxml的速度比较快，但其它的库处理有误的HTML或XML文件更好。

# %%
tables = pd.read_html('examples/fdic_failed_bank_list.html')
len(tables)
failures = tables[0]
failures.head()
# Out:
#                       Bank Name             City  ST   CERT  \
# 0                   Allied Bank         Mulberry  AR     91
# 1  The Woodbury Banking Company         Woodbury  GA  11297
# 2        First CornerStone Bank  King of Prussia  PA  35312
# 3            Trust Company Bank          Memphis  TN   9956
# 4    North Milwaukee State Bank        Milwaukee  WI  20364
#
#                  Acquiring Institution        Closing Date       Updated Date
# 0                         Today's Bank  September 23, 2016  November 17, 2016
# 1                          United Bank     August 19, 2016  November 17, 2016
# 2  First-Citizens Bank & Trust Company         May 6, 2016  September 6, 2016
# 3           The Bank of Fayette County      April 29, 2016  September 6, 2016
# 4  First-Citizens Bank & Trust Company      March 11, 2016      June 16, 2016

# %%
close_timestamps = pd.to_datetime(failures['Closing Date'])
close_timestamps.dt.year.value_counts()
# Out:
# 2010    157
# 2009    140
# 2011     92
# 2012     51
# 2008     25
# 2013     24
# 2014     18
# 2002     11
# 2015      8
# 2016      5
# 2001      4
# 2004      4
# 2003      3
# 2007      3
# 2000      2
# Name: Closing Date, dtype: int64

# %% [markdown]
# #### Parsing XML with lxml.objectify

# %% [markdown]
# <INDICATOR>
#   <INDICATOR_SEQ>373889</INDICATOR_SEQ>
#   <PARENT_SEQ></PARENT_SEQ>
#   <AGENCY_NAME>Metro-North Railroad</AGENCY_NAME>
#   <INDICATOR_NAME>Escalator Availability</INDICATOR_NAME>
#   <DESCRIPTION>Percent of the time that escalators are operational
#   systemwide. The availability rate is based on physical observations performed
#   the morning of regular business days only. This is a new indicator the agency
#   began reporting in 2009.</DESCRIPTION>
#   <PERIOD_YEAR>2011</PERIOD_YEAR>
#   <PERIOD_MONTH>12</PERIOD_MONTH>
#   <CATEGORY>Service Indicators</CATEGORY>
#   <FREQUENCY>M</FREQUENCY>
#   <DESIRED_CHANGE>U</DESIRED_CHANGE>
#   <INDICATOR_UNIT>%</INDICATOR_UNIT>
#   <DECIMAL_PLACES>1</DECIMAL_PLACES>
#   <YTD_TARGET>97.00</YTD_TARGET>
#   <YTD_ACTUAL></YTD_ACTUAL>
#   <MONTHLY_TARGET>97.00</MONTHLY_TARGET>
#   <MONTHLY_ACTUAL></MONTHLY_ACTUAL>
# </INDICATOR>

# %% [markdown]
# #### XML（Extensible Markup Language）是另一种常见的支持分层、嵌套数据以及元数据的结构化数据格式。
# #### 这个内容可以在需要用爬虫结果 再仔细学习。

# %%
from lxml import objectify

path = 'datasets/mta_perf/Performance_MNR.xml'
parsed = objectify.parse(open(path))
root = parsed.getroot()

# %%
data = []

skip_fields = ['PARENT_SEQ', 'INDICATOR_SEQ',
               'DESIRED_CHANGE', 'DECIMAL_PLACES']

for elt in root.INDICATOR:
    el_data = {}
    for child in elt.getchildren():
        if child.tag in skip_fields:
            continue
        el_data[child.tag] = child.pyval
    data.append(el_data)

# %%
perf = pd.DataFrame(data)
perf.head()
# Out:
#             AGENCY_NAME                        INDICATOR_NAME  \
# 0  Metro-North Railroad  On-Time Performance (West of Hudson)
# 1  Metro-North Railroad  On-Time Performance (West of Hudson)
# 2  Metro-North Railroad  On-Time Performance (West of Hudson)
# 3  Metro-North Railroad  On-Time Performance (West of Hudson)
# 4  Metro-North Railroad  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY INDICATOR_UNIT YTD_TARGET  \
# 0             1  Service Indicators         M              %       95.0
# 1             2  Service Indicators         M              %       95.0
# 2             3  Service Indicators         M              %       95.0
# 3             4  Service Indicators         M              %       95.0
# 4             5  Service Indicators         M              %       95.0
#
#   YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0       96.9           95.0           96.9
# 1       96.0           95.0           95.0
# 2       96.3           95.0           96.9
# 3       96.8           95.0           98.3
# 4       96.6           95.0           95.8

# %%
from io import StringIO
tag = '<a href="http://www.google.com">Google</a>'
root = objectify.parse(StringIO(tag)).getroot()

# %%
root
root.get('href')
root.text
# Out:
# 'Google'

# %% [markdown]
# ## Binary Data Formats

# %% [markdown]
# #### 实现数据的高效二进制格式存储最简单的办法之一是使用Python内置的pickle序列化。pandas对象都有一个用于将数据以pickle格式保存到磁盘上的to_pickle方法
# #### 使用 pandas.read_pickle 读取 被 pickle序列化的 数据
# #### 注意：pickle仅建议用于短期存储格式。其原因是很难保证该格式永远是稳定的；今天pickle的对象可能无法被后续版本的库unpickle出来。虽然我尽力保证这种事情不会发生在pandas中，但是今后的某个时候说不定还是得“打破”该pickle格式。

# %%
frame = pd.read_csv('examples/ex1.csv')
frame
frame.to_pickle('examples/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
pd.read_pickle('examples/frame_pickle')
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# !del examples\frame_pickle

# %% [markdown]
# #### pandas内置支持两个二进制数据格式：HDF5和MessagePack。
# #### 另外：pandas或NumPy数据的其它存储格式有：1. bcolz：一种可压缩的列存储二进制格式，基于Blosc压缩库。
# #### 2. Feather：我与R语言社区的Hadley Wickham设计的一种跨语言的列存储文件格式。Feather使用了Apache Arrow的列式内存格式。

# %% [markdown]
# ### Using HDF5 Format

# %% [markdown]
# #### HDF5是一种存储大规模科学数组数据的非常好的文件格式。它可以被作为C标准库，带有许多语言的接口，如Java、Python和MATLAB等。HDF5中的HDF指的是层次型数据格式（hierarchical data format）。每个HDF5文件都含有一个文件系统式的节点结构，它使你能够存储多个数据集并支持元数据。与其他简单格式相比，HDF5支持多种压缩器的即时压缩，还能更高效地存储重复模式数据。对于那些非常大的无法直接放入内存的数据集，HDF5就是不错的选择，因为它可以高效地分块读写。
# #### 虽然可以用PyTables或h5py库直接访问HDF5文件，pandas提供了更为高级的接口，可以简化存储Series和DataFrame对象。HDFStore类可以像字典一样，处理低级的细节。

# %%
frame = pd.DataFrame({'a': np.random.randn(100)})
store = pd.HDFStore('mydata.h5')
store['obj1'] = frame
store['obj1_col'] = frame['a']
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: mydata.h5

# %%
store['obj1']
# Out:
#            a
# 0  -0.204708
# 1   0.478943
# 2  -0.519439
# 3  -0.555730
# 4   1.965781
# ..       ...
# 95  0.795253
# 96  0.118110
# 97 -0.748532
# 98  0.584970
# 99  0.152677
#
# [100 rows x 1 columns]

# %% [markdown]
# #### HDFStore支持两种存储模式，'fixed'和'table'。后者通常会更慢，但是支持使用特殊语法进行查询操作
# #### put是store['obj2'] = frame方法的显示版本，允许我们设置其它的选项，比如格式。

# %%
store.put('obj2', frame, format='table')
store.select('obj2', where=['index >= 10 and index <= 15'])
store.close()

# %%
frame.to_hdf('mydata.h5', 'obj3', format='table')
pd.read_hdf('mydata.h5', 'obj3', where=['index < 5'])
# Out:
#           a
# 0 -0.204708
# 1  0.478943
# 2 -0.519439
# 3 -0.555730
# 4  1.965781

# %% [markdown]
# #### 笔记：如果你要处理的数据位于远程服务器，比如Amazon S3或HDFS，使用专门为分布式存储（比如Apache Parquet）的二进制格式也许更加合适。Python的Parquet和其它存储格式还在不断的发展之中，所以这本书中没有涉及。
# #### 如果需要本地处理海量数据，我建议你好好研究一下PyTables和h5py，看看它们能满足你的哪些需求。。由于许多数据分析问题都是IO密集型（而不是CPU密集型），利用HDF5这样的工具能显著提升应用程序的效率。
# #### 注意：HDF5不是数据库。它最适合用作“一次写多次读”的数据集。虽然数据可以在任何时候被添加到文件中，但如果同时发生多个写操作，文件就可能会被破坏。

# %%
import os
os.remove('mydata.h5')

# %% [markdown]
# ### Reading Microsoft Excel Files

# %% [markdown]
# #### 如果要读取一个文件中的多个表单，方法1：创建ExcelFile会更快，方法2：将文件名传递到pandas.read_excel

# %%
xlsx = pd.ExcelFile('examples/ex1.xlsx')

# %%
pd.read_excel(xlsx, 'Sheet1')
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %%
frame = pd.read_excel('examples/ex1.xlsx', 'Sheet1')
frame
# Out:
#    Unnamed: 0  a   b   c   d message
# 0           0  1   2   3   4   hello
# 1           1  5   6   7   8   world
# 2           2  9  10  11  12     foo

# %% [markdown]
# #### 如果要将pandas数据写入为Excel格式，方法1：你必须首先创建一个ExcelWriter，然后使用pandas对象的to_excel方法将数据写入到其中
# #### 方法2：还可以不使用ExcelWriter，而是传递文件的路径到to_excel

# %%
writer = pd.ExcelWriter('examples/ex2.xlsx')
frame.to_excel(writer, 'Sheet1')
writer.save()

# %%
frame.to_excel('examples/ex2.xlsx')

# %%
# !del examples\ex2.xlsx
# Out:
# E:\myCODEs\MyLearnDataAnalysis\pydata-book-2nd-edition\examples\ex2.xlsx
# 另一个程序正在使用此文件，进程无法访问。

# %% [markdown]
# ## Interacting with Web APIs

# %% [markdown]
# #### 许多网站都有一些通过JSON或其他格式提供数据的公共API。通过Python访问这些API的办法有不少。一个简单易用的办法（推荐）是requests包（http://docs.python-requests.org）。
# #### 响应对象的json方法会返回一个包含被解析过的JSON字典，加载到一个Python对象中

# %%
import requests
url = 'https://api.github.com/repos/pandas-dev/pandas/issues'
resp = requests.get(url)
resp
# Out:
# <Response [200]>

# %%
data = resp.json()
data[0]['title']
# Out:
# 'PERF: Series.mad'

# %%
issues = pd.DataFrame(data, columns=['number', 'title',
                                     'labels', 'state'])
issues
# Out:
#     number                                              title  \
# 0    43010                                   PERF: Series.mad
# 1    43009     POC: use github issue form for usage questions
# 2    43008  BUG: `equals` method failed for nested `Series...
# 3    43007  Backport PR #43005 on branch 1.3.x (CI: Run py...
# 4    43006        Testing to_datetime, converting none to NaT
# 5    43004  DOC: Update param doc of to_parquet about comp...
# 6    43003  DOC: Fixed all remaining GL02 documentation er...
# 7    43002               DISC: remove Index and EA subclasses
# 8    43001  DOC: update Ecosystem page, and define governance
# 9    43000                                     ENH: SQL apply
# 10   42999  TST: Fix test related to reverting fastparquet...
# 11   42998                             PERF: DataFrame.insert
# 12   42997  BUG:nlargest/nsmallest does not act according ...
# 13   42996  Add return_inverse to .unique in EA interface ...
# 14   42995           ENH: .to_csv open a pop-up window option
# 15   42994  Why can't write the dataframe into excel with ...
# 16   42988                  TST: refactor iris table creation
# 17   42986  BUG: AbstractMethodError msg should begin w/ '...
# 18   42982  BUG: pd.to_datetime with format doesn't work w...
# 19   42981  BUG GH#40498 Fillna other missing values not m...
# 20   42980  BUG: GroupBy.__iter__ doesn't work for dict in...
# 21   42979          DOC: updates documentations Closes #21749
# 22   42976  TST: use fixtures for some sql database connec...
# 23   42973  DIS: Should the keyword use_nullable_dtypes us...
# 24   42972  ENH: add kwarg `max_rows` `max_cols` to `Style...
# 25   42971  BUG: Different initialization methods lead to ...
# 26   42970  pandas.DataFrame.filter does not work with reg...
# 27   42968  Update Parquet pandas metadata description on ...
# 28   42965     How to add coroutines in apply lambda function
# 29   42964           ENH: conditional merge - initial concept
#
#                                                labels state
# 0                                                  []  open
# 1   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 2   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 3   [{'id': 48070600, 'node_id': 'MDU6TGFiZWw0ODA3...  open
# 4                                                  []  open
# 5                                                  []  open
# 6                                                  []  open
# 7   [{'id': 157369, 'node_id': 'MDU6TGFiZWwxNTczNj...  open
# 8   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 9   [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 10                                                 []  open
# 11  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 12  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 13                                                 []  open
# 14  [{'id': 76812, 'node_id': 'MDU6TGFiZWw3NjgxMg=...  open
# 15  [{'id': 34444536, 'node_id': 'MDU6TGFiZWwzNDQ0...  open
# 16                                                 []  open
# 17                                                 []  open
# 18  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 19                                                 []  open
# 20  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 21  [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 22  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 23  [{'id': 2301354, 'node_id': 'MDU6TGFiZWwyMzAxM...  open
# 24  [{'id': 13101118, 'node_id': 'MDU6TGFiZWwxMzEw...  open
# 25  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 685114413, 'node_id': 'MDU6TGFiZWw2ODU...  open
# 28  [{'id': 34444536, 'node_id': 'MDU6TGFiZWwzNDQ0...  open
# 29                                                 []  open

# %% [markdown]
# ## Interacting with Databases

# %% [markdown]
# #### 在商业场景下，大多数数据可能不是存储在文本或Excel文件中。基于SQL的关系型数据库（如SQL Server、PostgreSQL和MySQL等）使用非常广泛，其它一些数据库也很流行。数据库的选择通常取决于性能、数据完整性以及应用程序的伸缩性需求。
# #### 将数据从SQL加载到DataFrame的过程很简单，此外pandas还有一些能够简化该过程的函数。例如，我将使用SQLite数据库（通过Python内置的sqlite3驱动器）
# #### 从表中选取数据时，大部分Python SQL驱动器（PyODBC、psycopg2、MySQLdb、pymssql等）都会返回一个元组列表
# #### 你可以将这个元组列表传给DataFrame构造器，但还需要列名（位于光标的description属性中）
# #### 这种数据规整操作相当多，你肯定不想每查一次数据库就重写一次。SQLAlchemy项目是一个流行的Python SQL工具，它抽象出了SQL数据库中的许多常见差异。pandas有一个read_sql函数，可以让你轻松的从SQLAlchemy连接读取数据。这里，我们用SQLAlchemy连接SQLite数据库，并从之前创建的表读取数据

# %%
import sqlite3
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
 c REAL,        d INTEGER
);"""
con = sqlite3.connect('mydata.sqlite')
con.execute(query)
con.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
        ('Tallahassee', 'Florida', 2.6, 3),
        ('Sacramento', 'California', 1.7, 5)]
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"
con.executemany(stmt, data)
con.commit()

# %%
cursor = con.execute('select * from test')
rows = cursor.fetchall()
rows
# Out:
# [('Atlanta', 'Georgia', 1.25, 6),
#  ('Tallahassee', 'Florida', 2.6, 3),
#  ('Sacramento', 'California', 1.7, 5)]

# %%
cursor.description
pd.DataFrame(rows, columns=[x[0] for x in cursor.description])
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
import sqlalchemy as sqla
db = sqla.create_engine('sqlite:///mydata.sqlite')
pd.read_sql('select * from test', db)
# Out:
#              a           b     c  d
# 0      Atlanta     Georgia  1.25  6
# 1  Tallahassee     Florida  2.60  3
# 2   Sacramento  California  1.70  5

# %%
# !del mydata.sqlite
# Out:
# E:\myCODEs\MyLearnDataAnalysis\pydata-book-2nd-edition\mydata.sqlite
# 另一个程序正在使用此文件，进程无法访问。

# %% [markdown]
# ## Conclusion
